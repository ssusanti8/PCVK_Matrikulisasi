# %% [markdown]
# <a href="https://colab.research.google.com/github/ssusanti8/PCVK_Matrikulisasi/blob/main/jobsheet5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #Praktikum 1

# %%
original= cv.imread('/content/drive/MyDrive/Images/female.tiff')
gamma_corrected = np.zeros(original.shape, original.dtype)

print(' Gamma Correction pada citra ')
print('----------------------------------')
try:
  gamma = int(input('Masukkan nilai Gamma: '))
except ValueError:
  print('Error, not a number')

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      gamma_corrected[y,x,c] = np.clip(255 * pow(original[y,x,c]/255, (1/gamma)),0,255);

final_frame = cv.hconcat((original, gamma_corrected))
cv2_imshow(final_frame)
# Out:
#  Gamma Correction pada citra
# ----------------------------------
# Masukkan nilai Gamma: 3
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FE0A3100250>

# %% [markdown]
# #PRAKTIKUM 2

# %%
image = cv.imread('/content/drive/MyDrive/Images/female.tiff')
depth_image = np.zeros(image.shape, image.dtype)

print('Image Depth pada citra ')
print('--------------------------')
try:
  bd = float(input('Input bit depth value : '))
except ValueError:
  print('Error, not a number')
# bit=pow(2,bd)
bit=2**bd
level = 255/(bit-1)
for y in range(image.shape[0]):
  for x in range(image.shape[1]):
    for c in range(image.shape[2]):
      depth_image[y,x,c] = np.clip(round(image[y,x,c]/level)*level,0,255);

final_frame = cv.hconcat((image, depth_image))
cv2_imshow(final_frame)
# Out:
# Image Depth pada citra
# --------------------------
# Input bit depth value : 3
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FE0A302D050>

# %% [markdown]
# #PRAKTIKUM 3

# %%
original= cv.imread('/content/drive/MyDrive/Images/galaxy.jpg')
gamma_corrected = np.zeros(original.shape, original.dtype)

print(' Gamma Average Denoising ')
print('----------------------------------')
try:
  gamma = int(input('Masukkan nilai Gamma: '))
except ValueError:
  print('Error, not a number')

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      def PSNR(img1, img2): 
        mse = np.mean((img1 - img2) ** 2) 
        if(mse == 0): # MSE 0 maka tidak ada noise sama sekali, sehingga PSNR tidak memiliki arti 
          return 100 
        max_pixel = 255.0 
        psnr = 20 * log10(max_pixel / sqrt(mse)) 
        return psnr

final_frame = cv.hconcat((original, PNSR))
cv2_imshow(final_frame)
# Out:
#  Gamma Average Denoising
# ----------------------------------
# Masukkan nilai Gamma: 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-2612372c59d7> in <module>
#      20         return psnr
#      21
# ---> 22 final_frame = cv.hconcat((original, PNSR))
#      23 cv2_imshow(final_frame)
#
# NameError: name 'PNSR' is not defined
